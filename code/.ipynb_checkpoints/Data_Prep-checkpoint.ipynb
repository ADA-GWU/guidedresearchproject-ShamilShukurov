# %%
import pandas as pd
import numpy as np
import sweetviz as sv
from scipy import stats

# %%
red_wine\
=pd.read_csv(
    r"C:\Users\SukurovSB\Desktop\Guided_Research\guidedresearchproject-ShamilShukurov\data\winequality-red.csv", 
    delimiter=";"
)

# %%
white_wine\
=pd.read_csv(
    r"C:\Users\SukurovSB\Desktop\Guided_Research\guidedresearchproject-ShamilShukurov\data\winequality-white.csv", 
    delimiter=";"
)

# %%
red_wine.quality.value_counts()/red_wine.quality.value_counts().sum()
# Out:
# 5    0.425891
# 6    0.398999
# 7    0.124453
# 4    0.033146
# 8    0.011257
# 3    0.006254
# Name: quality, dtype: float64

# %%
white_wine.quality.value_counts()/white_wine.quality.value_counts().sum()
# Out:
# 6    0.448755
# 5    0.297468
# 7    0.179665
# 8    0.035729
# 4    0.033279
# 3    0.004083
# 9    0.001021
# Name: quality, dtype: float64

# %%
wine_df = pd.concat([red_wine, white_wine])

# %%
wine_df["target"] = np.where(wine_df.quality<=4,0,1)

# %%
wine_df.target.value_counts()/wine_df.target.value_counts().sum()
# Out:
# 1    0.962136
# 0    0.037864
# Name: target, dtype: float64

# %%
if "quality" in wine_df.columns:
    wine_df.drop(columns="quality",inplace=True)

# %%
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
wine_df.to_csv(r"C:\Users\SukurovSB\Desktop\Guided_Research\guidedresearchproject-ShamilShukurov\data\saved_datasets\wine.csv")

# %%
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
analyze_report = sv.analyze(wine_df, target_feat="target")
analyze_report.show_html('wine_data_eda.html', open_browser=False)
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report wine_data_eda.html was generated.

# %%
wine_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
for col in wine_df.columns[:-1]:
    t = stats.ttest_ind(wine_df[wine_df.target==1][col],wine_df[wine_df.target==0][col])
    print("Column:{}\nt:{}\np_value:{}".format(col,t.statistic.round(4),t.pvalue.round(4)))
    print("===========================")
# Out:
# Column:fixed acidity
# t:-1.7568
# p_value:0.079
# ...
# Column:volatile acidity
# t:-12.3295
# p_value:0.0
# ...
# Column:citric acid
# t:4.9892
# p_value:0.0
# ...
# Column:residual sugar
# t:3.934
# p_value:0.0001
# ...
# Column:chlorides
# t:-2.782
# p_value:0.0054
# ...
# Column:free sulfur dioxide
# t:6.8918
# p_value:0.0
# ...
# Column:total sulfur dioxide
# t:2.8428
# p_value:0.0045
# ...
# Column:density
# t:-1.318
# p_value:0.1876
# ...
# Column:pH
# t:-1.6208
# p_value:0.1051
# ...
# Column:sulphates
# t:2.7454
# p_value:0.0061
# ...
# Column:alcohol
# t:4.1269
# p_value:0.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
for col in wine_df.columns[:-1]:
    title = "{} vs target".format(col)
    sns.boxplot(data=wine_df,x="target",y=col).set_title(title)
    plt.show()
