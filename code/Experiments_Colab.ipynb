# %%
from modelling import *
import pandas as pd

# %%
dataset_infos = pd.read_csv("dataset_infos.csv").drop(columns="Unnamed: 0")
dataset_infos
# Out:
#        Dataset_Name  Row_Count  Minority_Class_Percent Target_Column
# 0           Abalone       1477                   4.520        target
# 1             Adult      32561                  24.080        target
# 2             Churn       7043                  26.530        target
# 3     Contraceptive       1743                  22.600        target
# 4         Covertype     581012                  14.770        target
# 5             Fraud     284807                   0.172         Class
# 6            Fraud2     250000                   0.500      is_fraud
# 7          Letter-a      20000                   3.940      letter_a
# 8      Letter-vowel      20000                  19.390      is_vowel
# 9         Pendigits      10992                   9.590          is_9
# 10   Sick_euthyroid       2194                  10.050        target
# 11  Splice-junction       3186                  24.070        target
# 12             Wine       6497                   3.760        target

# %%
reports = []

# %%
fraud_train = pd.read_csv("fraud_train.csv")
fraud_test = pd.read_csv("fraud_test.csv")

# %%
rep_fraud = built_experiment(fraud_train, fraud_test, "Class","Fraud")
reports.append(rep_fraud)
# Out:
# Running Experiment...
# Dataset Name: Fraud
# Target Column: Class
# Building LGBM Model...
# ROC Curve for test data: 0.6762797092669368
# Saving model as pickle...
# Upsampling is being applied...
# Building LGBM Upsample Model...
# ROC Curve for test data: 0.9527300368656185
# Saving model as pickle...
# Downsampling is being applied...
# Building LGBM Downsample Model...
# ROC Curve for test data: 0.9849102907904862
# Saving model as pickle...
# SMOTE is being applied...
# Building SMOTE LGBM Model...
# ROC Curve for test data: 0.9729360529383391
# Saving model as pickle...
# Building LGBM Balanced Bagging Model...
# ROC Curve for test data: 0.9138691457168124
# Saving model as pickle...
# /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# ...

# %%
pd.concat(reports)
# Out:
#   Dataset                  Model   f1_test  f1_train  accuracy_test  \
# 0   Fraud          LGBM Baseline  0.328889  0.328289       0.997349
# 1   Fraud          LGBM Upsample  0.866310  0.999960       0.999561
# 2   Fraud        LGBM Downsample  0.089277  1.000000       0.967048
# 3   Fraud             SMOTE LGBM  0.753363  0.999727       0.999034
# 4   Fraud  LGBM Balanced Bagging  0.510949  0.576450       0.998824
# 5   Fraud         LGBM_Imbalance  0.061005  0.065295       0.952442
#
#    accuracy_train  AUC_test  AUC_train
# 0        0.997468  0.676280   0.665090
# 1        0.999960  0.952730   1.000000
# 2        1.000000  0.984910   1.000000
# 3        0.999727  0.972936   0.999864
# 4        0.998942  0.913869   0.971794
# 5        0.952753  0.915675   0.954766

# %%
letter_a_train = pd.read_csv("letter_a_train.csv")
letter_a_test = pd.read_csv("letter_a_test.csv")

# %%
rep_letter_a = built_experiment(letter_a_train, letter_a_test, "letter_a","Letter-a")
reports.append(rep_letter_a)
# Out:
# Running Experiment...
# Dataset Name: Letter-a
# Target Column: letter_a
# Building LGBM Model...
# ROC Curve for test data: 0.999968630130063
# Saving model as pickle...
# Upsampling is being applied...
# Building LGBM Upsample Model...
# ROC Curve for test data: 0.9999512024245424
# Saving model as pickle...
# Downsampling is being applied...
# Building LGBM Downsample Model...
# ROC Curve for test data: 0.9998745205202519
# Saving model as pickle...
# SMOTE is being applied...
# Building SMOTE LGBM Model...
# ROC Curve for test data: 0.9999529451950944
# Saving model as pickle...
# Building LGBM Balanced Bagging Model...
# ROC Curve for test data: 0.9999546879656465
# Saving model as pickle...
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 640, number of negative: 15360
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000342 seconds.
# ...

# %%
pd.concat(reports)
# Out:
#     Dataset                  Model   f1_test  f1_train  accuracy_test  \
# 0     Fraud          LGBM Baseline  0.328889  0.328289       0.997349
# 1     Fraud          LGBM Upsample  0.866310  0.999960       0.999561
# 2     Fraud        LGBM Downsample  0.089277  1.000000       0.967048
# 3     Fraud             SMOTE LGBM  0.753363  0.999727       0.999034
# 4     Fraud  LGBM Balanced Bagging  0.510949  0.576450       0.998824
# 5     Fraud         LGBM_Imbalance  0.061005  0.065295       0.952442
# 0  Letter-a          LGBM Baseline  0.979730  1.000000       0.998500
# 1  Letter-a          LGBM Upsample  0.986577  1.000000       0.999000
# 2  Letter-a        LGBM Downsample  0.832402  1.000000       0.985000
# 3  Letter-a             SMOTE LGBM  0.986667  1.000000       0.999000
# 4  Letter-a  LGBM Balanced Bagging  0.983165  0.998435       0.998750
# 5  Letter-a         LGBM_Imbalance  0.986577  1.000000       0.999000
#
#    accuracy_train  AUC_test  AUC_train
# ...

# %%
dataset_infos
# Out:
#        Dataset_Name  Row_Count  Minority_Class_Percent Target_Column
# 0           Abalone       1477                   4.520        target
# 1             Adult      32561                  24.080        target
# 2             Churn       7043                  26.530        target
# 3     Contraceptive       1743                  22.600        target
# 4         Covertype     581012                  14.770        target
# 5             Fraud     284807                   0.172         Class
# 6            Fraud2     250000                   0.500      is_fraud
# 7          Letter-a      20000                   3.940      letter_a
# 8      Letter-vowel      20000                  19.390      is_vowel
# 9         Pendigits      10992                   9.590          is_9
# 10   Sick_euthyroid       2194                  10.050        target
# 11  Splice-junction       3186                  24.070        target
# 12             Wine       6497                   3.760        target

# %%
wine_train = pd.read_csv("wine_train.csv")
wine_test = pd.read_csv("wine_train.csv")

# %%
wine_train.target = np.abs(wine_train.target-1)
wine_test.target = np.abs(wine_test.target-1)

# %%
wine_train.target.value_counts()
# Out:
# 0    5000
# 1     197
# Name: target, dtype: int64

# %%
rep_wine = built_experiment(wine_train, wine_test, "target","Wine")
reports.append(rep_wine)
# Out:
# Running Experiment...
# Dataset Name: Wine
# Target Column: target
# Building LGBM Model...
# ROC Curve for test data: 1.0
# Saving model as pickle...
# Upsampling is being applied...
# Building LGBM Upsample Model...
# ROC Curve for test data: 1.0
# Saving model as pickle...
# Downsampling is being applied...
# Building LGBM Downsample Model...
# ROC Curve for test data: 0.9545086294416244
# Saving model as pickle...
# SMOTE is being applied...
# Building SMOTE LGBM Model...
# ROC Curve for test data: 0.9964284263959391
# Saving model as pickle...
# Building LGBM Balanced Bagging Model...
# ROC Curve for test data: 0.9999441624365483
# Saving model as pickle...
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 197, number of negative: 5000
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000294 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# ...

# %%
pd.concat(reports)
# Out:
#     Dataset                  Model   f1_test  f1_train  accuracy_test  \
# 0     Fraud          LGBM Baseline  0.328889  0.328289       0.997349
# 1     Fraud          LGBM Upsample  0.866310  0.999960       0.999561
# 2     Fraud        LGBM Downsample  0.089277  1.000000       0.967048
# 3     Fraud             SMOTE LGBM  0.753363  0.999727       0.999034
# 4     Fraud  LGBM Balanced Bagging  0.510949  0.576450       0.998824
# 5     Fraud         LGBM_Imbalance  0.061005  0.065295       0.952442
# 0  Letter-a          LGBM Baseline  0.979730  1.000000       0.998500
# 1  Letter-a          LGBM Upsample  0.986577  1.000000       0.999000
# 2  Letter-a        LGBM Downsample  0.832402  1.000000       0.985000
# 3  Letter-a             SMOTE LGBM  0.986667  1.000000       0.999000
# 4  Letter-a  LGBM Balanced Bagging  0.983165  0.998435       0.998750
# 5  Letter-a         LGBM_Imbalance  0.986577  1.000000       0.999000
# ...

# %%
dataset_infos
# Out:
#        Dataset_Name  Row_Count  Minority_Class_Percent Target_Column
# 0           Abalone       1477                   4.520        target
# 1             Adult      32561                  24.080        target
# 2             Churn       7043                  26.530        target
# 3     Contraceptive       1743                  22.600        target
# 4         Covertype     581012                  14.770        target
# 5             Fraud     284807                   0.172         Class
# 6            Fraud2     250000                   0.500      is_fraud
# 7          Letter-a      20000                   3.940      letter_a
# 8      Letter-vowel      20000                  19.390      is_vowel
# 9         Pendigits      10992                   9.590          is_9
# 10   Sick_euthyroid       2194                  10.050        target
# 11  Splice-junction       3186                  24.070        target
# 12             Wine       6497                   3.760        target

# %%
abalone_train = pd.read_csv("abalone_train.csv")
abalone_test = pd.read_csv("abalone_test.csv")

# %%
abalone_train.target.value_counts()
# Out:
# 0    3200
# 1     141
# Name: target, dtype: int64

# %%
rep_abalone =  built_experiment(abalone_train, abalone_test, "target","Abalone")
reports.append(rep_abalone)
# Out:
# Running Experiment...
# Dataset Name: Abalone
# Target Column: target
# Building LGBM Model...
# ROC Curve for test data: 0.9850888324873097
# Saving model as pickle...
# Upsampling is being applied...
# Building LGBM Upsample Model...
# ROC Curve for test data: 0.98582910321489
# Saving model as pickle...
# Downsampling is being applied...
# Building LGBM Downsample Model...
# ROC Curve for test data: 0.9830134306260576
# Saving model as pickle...
# SMOTE is being applied...
# Building SMOTE LGBM Model...
# ROC Curve for test data: 0.9856969120135364
# Saving model as pickle...
# Building LGBM Balanced Bagging Model...
# ROC Curve for test data: 0.9874153976311337
# Saving model as pickle...
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 141, number of negative: 3200
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000214 seconds.
# ...

# %%
pd.concat(reports)
# Out:
#     Dataset                  Model   f1_test  f1_train  accuracy_test  \
# 0     Fraud          LGBM Baseline  0.328889  0.328289       0.997349
# 1     Fraud          LGBM Upsample  0.866310  0.999960       0.999561
# 2     Fraud        LGBM Downsample  0.089277  1.000000       0.967048
# 3     Fraud             SMOTE LGBM  0.753363  0.999727       0.999034
# 4     Fraud  LGBM Balanced Bagging  0.510949  0.576450       0.998824
# 5     Fraud         LGBM_Imbalance  0.061005  0.065295       0.952442
# 0  Letter-a          LGBM Baseline  0.979730  1.000000       0.998500
# 1  Letter-a          LGBM Upsample  0.986577  1.000000       0.999000
# 2  Letter-a        LGBM Downsample  0.832402  1.000000       0.985000
# 3  Letter-a             SMOTE LGBM  0.986667  1.000000       0.999000
# 4  Letter-a  LGBM Balanced Bagging  0.983165  0.998435       0.998750
# 5  Letter-a         LGBM_Imbalance  0.986577  1.000000       0.999000
# ...

# %%
dataset_infos
# Out:
#        Dataset_Name  Row_Count  Minority_Class_Percent Target_Column
# 0           Abalone       1477                   4.520        target
# 1             Adult      32561                  24.080        target
# 2             Churn       7043                  26.530        target
# 3     Contraceptive       1743                  22.600        target
# 4         Covertype     581012                  14.770        target
# 5             Fraud     284807                   0.172         Class
# 6            Fraud2     250000                   0.500      is_fraud
# 7          Letter-a      20000                   3.940      letter_a
# 8      Letter-vowel      20000                  19.390      is_vowel
# 9         Pendigits      10992                   9.590          is_9
# 10   Sick_euthyroid       2194                  10.050        target
# 11  Splice-junction       3186                  24.070        target
# 12             Wine       6497                   3.760        target

# %%
pendigits_train = pd.read_csv("pendigits_train.csv")
pendigits_test = pd.read_csv("pendigits_test.csv")

# %%
pendigits_train.is_9.value_counts()
# Out:
# 0    7964
# 1     829
# Name: is_9, dtype: int64

# %%
rep_pend =  built_experiment(pendigits_train, pendigits_test, "is_9","Pendigits")
reports.append(rep_pend)
# Out:
# Running Experiment...
# Dataset Name: Pendigits
# Target Column: is_9
# Building LGBM Model...
# ROC Curve for test data: 0.9998116161095139
# Saving model as pickle...
# Upsampling is being applied...
# Building LGBM Upsample Model...
# ROC Curve for test data: 0.999840770759232
# Saving model as pickle...
# Downsampling is being applied...
# Building LGBM Downsample Model...
# ROC Curve for test data: 0.9995985629000355
# Saving model as pickle...
# SMOTE is being applied...
# Building SMOTE LGBM Model...
# ROC Curve for test data: 0.999872168074313
# Saving model as pickle...
# Building LGBM Balanced Bagging Model...
# ROC Curve for test data: 0.9997645201368922
# Saving model as pickle...
# [LightGBM] [Info] Number of positive: 829, number of negative: 7964
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000591 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1488
# ...

# %%
pd.concat(reports)
# Out:
#      Dataset                  Model   f1_test  f1_train  accuracy_test  \
# 0      Fraud          LGBM Baseline  0.328889  0.328289       0.997349
# 1      Fraud          LGBM Upsample  0.866310  0.999960       0.999561
# 2      Fraud        LGBM Downsample  0.089277  1.000000       0.967048
# 3      Fraud             SMOTE LGBM  0.753363  0.999727       0.999034
# 4      Fraud  LGBM Balanced Bagging  0.510949  0.576450       0.998824
# 5      Fraud         LGBM_Imbalance  0.061005  0.065295       0.952442
# 0   Letter-a          LGBM Baseline  0.979730  1.000000       0.998500
# 1   Letter-a          LGBM Upsample  0.986577  1.000000       0.999000
# 2   Letter-a        LGBM Downsample  0.832402  1.000000       0.985000
# 3   Letter-a             SMOTE LGBM  0.986667  1.000000       0.999000
# 4   Letter-a  LGBM Balanced Bagging  0.983165  0.998435       0.998750
# 5   Letter-a         LGBM_Imbalance  0.986577  1.000000       0.999000
# ...

# %%
dataset_infos
# Out:
#        Dataset_Name  Row_Count  Minority_Class_Percent Target_Column
# 0           Abalone       1477                   4.520        target
# 1             Adult      32561                  24.080        target
# 2             Churn       7043                  26.530        target
# 3     Contraceptive       1743                  22.600        target
# 4         Covertype     581012                  14.770        target
# 5             Fraud     284807                   0.172         Class
# 6            Fraud2     250000                   0.500      is_fraud
# 7          Letter-a      20000                   3.940      letter_a
# 8      Letter-vowel      20000                  19.390      is_vowel
# 9         Pendigits      10992                   9.590          is_9
# 10   Sick_euthyroid       2194                  10.050        target
# 11  Splice-junction       3186                  24.070        target
# 12             Wine       6497                   3.760        target

# %%
sick_train = pd.read_csv("sick_euthyroid_train.csv")
sick_test = pd.read_csv("sick_euthyroid_test.csv")

# %%
sick_train.target.value_counts()
# Out:
# 0    2099
# 1     232
# Name: target, dtype: int64

# %%
rep_sick = built_experiment(sick_train, sick_test, "target","Sick_euthyroid")
reports.append(rep_sick)
# Out:
# Running Experiment...
# Dataset Name: Sick_euthyroid
# Target Column: target
# Building LGBM Model...
# ROC Curve for test data: 0.8735946234533006
# Saving model as pickle...
# Upsampling is being applied...
# Building LGBM Upsample Model...
# ROC Curve for test data: 0.8714904842660637
# Saving model as pickle...
# Downsampling is being applied...
# Building LGBM Downsample Model...
# ROC Curve for test data: 0.8515482695810564
# Saving model as pickle...
# SMOTE is being applied...
# Building SMOTE LGBM Model...
# ROC Curve for test data: 0.8794045600150744
# Saving model as pickle...
# Building LGBM Balanced Bagging Model...
# ROC Curve for test data: 0.8870673952641166
# Saving model as pickle...
# [LightGBM] [Info] Number of positive: 232, number of negative: 2099
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000303 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# ...

# %%
pd.concat(reports)
# Out:
#           Dataset                  Model   f1_test  f1_train  accuracy_test  \
# 0           Fraud          LGBM Baseline  0.328889  0.328289       0.997349
# 1           Fraud          LGBM Upsample  0.866310  0.999960       0.999561
# 2           Fraud        LGBM Downsample  0.089277  1.000000       0.967048
# 3           Fraud             SMOTE LGBM  0.753363  0.999727       0.999034
# 4           Fraud  LGBM Balanced Bagging  0.510949  0.576450       0.998824
# 5           Fraud         LGBM_Imbalance  0.061005  0.065295       0.952442
# 0        Letter-a          LGBM Baseline  0.979730  1.000000       0.998500
# 1        Letter-a          LGBM Upsample  0.986577  1.000000       0.999000
# 2        Letter-a        LGBM Downsample  0.832402  1.000000       0.985000
# 3        Letter-a             SMOTE LGBM  0.986667  1.000000       0.999000
# 4        Letter-a  LGBM Balanced Bagging  0.983165  0.998435       0.998750
# ...

# %%
dataset_infos
# Out:
#        Dataset_Name  Row_Count  Minority_Class_Percent Target_Column
# 0           Abalone       1477                   4.520        target
# 1             Adult      32561                  24.080        target
# 2             Churn       7043                  26.530        target
# 3     Contraceptive       1743                  22.600        target
# 4         Covertype     581012                  14.770        target
# 5             Fraud     284807                   0.172         Class
# 6            Fraud2     250000                   0.500      is_fraud
# 7          Letter-a      20000                   3.940      letter_a
# 8      Letter-vowel      20000                  19.390      is_vowel
# 9         Pendigits      10992                   9.590          is_9
# 10   Sick_euthyroid       2194                  10.050        target
# 11  Splice-junction       3186                  24.070        target
# 12             Wine       6497                   3.760        target

# %%
covertype_train = pd.read_csv("covertype_train.csv")
covertype_test = pd.read_csv("covertype_test.csv")

# %%
covertype_train.target.value_counts()
# Out:
# 0    396084
# 1     68725
# Name: target, dtype: int64

# %%
rep_cov = built_experiment(covertype_train, covertype_test, "target","Covertype")
reports.append(rep_cov)
# Out:
# Running Experiment...
# Dataset Name: Covertype
# Target Column: target
# Building LGBM Model...
# ROC Curve for test data: 0.9899867025650625
# Saving model as pickle...
# Upsampling is being applied...
# Building LGBM Upsample Model...
# ROC Curve for test data: 0.9897121548138759
# Saving model as pickle...
# Downsampling is being applied...
# Building LGBM Downsample Model...
# ROC Curve for test data: 0.989332813010852
# Saving model as pickle...
# SMOTE is being applied...
# Building SMOTE LGBM Model...
# ROC Curve for test data: 0.9890749856884705
# Saving model as pickle...
# Building LGBM Balanced Bagging Model...
# ROC Curve for test data: 0.9910669796868007
# Saving model as pickle...
# /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# ...

# %%
pd.concat(reports)
# Out:
#           Dataset                  Model   f1_test  f1_train  accuracy_test  \
# 0           Fraud          LGBM Baseline  0.328889  0.328289       0.997349
# 1           Fraud          LGBM Upsample  0.866310  0.999960       0.999561
# 2           Fraud        LGBM Downsample  0.089277  1.000000       0.967048
# 3           Fraud             SMOTE LGBM  0.753363  0.999727       0.999034
# 4           Fraud  LGBM Balanced Bagging  0.510949  0.576450       0.998824
# 5           Fraud         LGBM_Imbalance  0.061005  0.065295       0.952442
# 0        Letter-a          LGBM Baseline  0.979730  1.000000       0.998500
# 1        Letter-a          LGBM Upsample  0.986577  1.000000       0.999000
# 2        Letter-a        LGBM Downsample  0.832402  1.000000       0.985000
# 3        Letter-a             SMOTE LGBM  0.986667  1.000000       0.999000
# 4        Letter-a  LGBM Balanced Bagging  0.983165  0.998435       0.998750
# ...

# %%
dataset_infos
# Out:
#        Dataset_Name  Row_Count  Minority_Class_Percent Target_Column
# 0           Abalone       1477                   4.520        target
# 1             Adult      32561                  24.080        target
# 2             Churn       7043                  26.530        target
# 3     Contraceptive       1743                  22.600        target
# 4         Covertype     581012                  14.770        target
# 5             Fraud     284807                   0.172         Class
# 6            Fraud2     250000                   0.500      is_fraud
# 7          Letter-a      20000                   3.940      letter_a
# 8      Letter-vowel      20000                  19.390      is_vowel
# 9         Pendigits      10992                   9.590          is_9
# 10   Sick_euthyroid       2194                  10.050        target
# 11  Splice-junction       3186                  24.070        target
# 12             Wine       6497                   3.760        target

# %%
letter_vowel_train = pd.read_csv("letter_vowel_train.csv")
letter_vowel_test = pd.read_csv("letter_vowel_test.csv")

# %%
rep_vowel = built_experiment(letter_vowel_train, letter_vowel_test, "is_vowel","Letter-vowel")
reports.append(rep_vowel)
# Out:
# Running Experiment...
# Dataset Name: Letter-vowel
# Target Column: is_vowel
# Building LGBM Model...
# ROC Curve for test data: 0.9945136196843107
# Saving model as pickle...
# Upsampling is being applied...
# Building LGBM Upsample Model...
# ROC Curve for test data: 0.9945941114037756
# Saving model as pickle...
# Downsampling is being applied...
# Building LGBM Downsample Model...
# ROC Curve for test data: 0.9933005811583042
# Saving model as pickle...
# SMOTE is being applied...
# Building SMOTE LGBM Model...
# ROC Curve for test data: 0.9908975595234243
# Saving model as pickle...
# Building LGBM Balanced Bagging Model...
# ROC Curve for test data: 0.9955632478853733
# Saving model as pickle...
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 3114, number of negative: 12886
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000350 seconds.
# ...

# %%
pd.concat(reports)
# Out:
#           Dataset                  Model   f1_test  f1_train  accuracy_test  \
# 0           Fraud          LGBM Baseline  0.328889  0.328289       0.997349
# 1           Fraud          LGBM Upsample  0.866310  0.999960       0.999561
# 2           Fraud        LGBM Downsample  0.089277  1.000000       0.967048
# 3           Fraud             SMOTE LGBM  0.753363  0.999727       0.999034
# 4           Fraud  LGBM Balanced Bagging  0.510949  0.576450       0.998824
# 5           Fraud         LGBM_Imbalance  0.061005  0.065295       0.952442
# 0        Letter-a          LGBM Baseline  0.979730  1.000000       0.998500
# 1        Letter-a          LGBM Upsample  0.986577  1.000000       0.999000
# 2        Letter-a        LGBM Downsample  0.832402  1.000000       0.985000
# 3        Letter-a             SMOTE LGBM  0.986667  1.000000       0.999000
# 4        Letter-a  LGBM Balanced Bagging  0.983165  0.998435       0.998750
# ...

# %%
dataset_infos
# Out:
#        Dataset_Name  Row_Count  Minority_Class_Percent Target_Column
# 0           Abalone       1477                   4.520        target
# 1             Adult      32561                  24.080        target
# 2             Churn       7043                  26.530        target
# 3     Contraceptive       1743                  22.600        target
# 4         Covertype     581012                  14.770        target
# 5             Fraud     284807                   0.172         Class
# 6            Fraud2     250000                   0.500      is_fraud
# 7          Letter-a      20000                   3.940      letter_a
# 8      Letter-vowel      20000                  19.390      is_vowel
# 9         Pendigits      10992                   9.590          is_9
# 10   Sick_euthyroid       2194                  10.050        target
# 11  Splice-junction       3186                  24.070        target
# 12             Wine       6497                   3.760        target

# %%
contraceptive_train = pd.read_csv("contraceptive_train.csv")
contraceptive_test = pd.read_csv("contraceptive_test.csv")

# %%
contraceptive_train.target.value_counts()
# Out:
# 0    916
# 1    262
# Name: target, dtype: int64

# %%
rep_contr = built_experiment(contraceptive_train, contraceptive_test, "target","Contraceptive")
reports.append(rep_contr)
# Out:
# Running Experiment...
# Dataset Name: Contraceptive
# Target Column: target
# Building LGBM Model...
# ROC Curve for test data: 0.7418888329979879
# Saving model as pickle...
# Upsampling is being applied...
# Building LGBM Upsample Model...
# ROC Curve for test data: 0.7792379275653925
# Saving model as pickle...
# Downsampling is being applied...
# Building LGBM Downsample Model...
# ROC Curve for test data: 0.7349723340040242
# Saving model as pickle...
# SMOTE is being applied...
# Building SMOTE LGBM Model...
# ROC Curve for test data: 0.7490568410462776
# Saving model as pickle...
# Building LGBM Balanced Bagging Model...
# ROC Curve for test data: 0.7632671026156942
# Saving model as pickle...
# [LightGBM] [Info] Number of positive: 262, number of negative: 916
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000159 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# ...

# %%
pd.concat(reports)
# Out:
#           Dataset                  Model   f1_test  f1_train  accuracy_test  \
# 0           Fraud          LGBM Baseline  0.328889  0.328289       0.997349
# 1           Fraud          LGBM Upsample  0.866310  0.999960       0.999561
# 2           Fraud        LGBM Downsample  0.089277  1.000000       0.967048
# 3           Fraud             SMOTE LGBM  0.753363  0.999727       0.999034
# 4           Fraud  LGBM Balanced Bagging  0.510949  0.576450       0.998824
# 5           Fraud         LGBM_Imbalance  0.061005  0.065295       0.952442
# 0        Letter-a          LGBM Baseline  0.979730  1.000000       0.998500
# 1        Letter-a          LGBM Upsample  0.986577  1.000000       0.999000
# 2        Letter-a        LGBM Downsample  0.832402  1.000000       0.985000
# 3        Letter-a             SMOTE LGBM  0.986667  1.000000       0.999000
# 4        Letter-a  LGBM Balanced Bagging  0.983165  0.998435       0.998750
# ...

# %%
dataset_infos
# Out:
#        Dataset_Name  Row_Count  Minority_Class_Percent Target_Column
# 0           Abalone       1477                   4.520        target
# 1             Adult      32561                  24.080        target
# 2             Churn       7043                  26.530        target
# 3     Contraceptive       1743                  22.600        target
# 4         Covertype     581012                  14.770        target
# 5             Fraud     284807                   0.172         Class
# 6            Fraud2     250000                   0.500      is_fraud
# 7          Letter-a      20000                   3.940      letter_a
# 8      Letter-vowel      20000                  19.390      is_vowel
# 9         Pendigits      10992                   9.590          is_9
# 10   Sick_euthyroid       2194                  10.050        target
# 11  Splice-junction       3186                  24.070        target
# 12             Wine       6497                   3.760        target

# %%
splice_train = pd.read_csv("splice_train.csv")
splice_test = pd.read_csv("splice_train.csv")

# %%
rep_splice = built_experiment(splice_train, splice_test, "target","Splice-junction")
reports.append(rep_splice)
# Out:
# Running Experiment...
# Dataset Name: Splice-junction
# Target Column: target
# Building LGBM Model...
# ROC Curve for test data: 1.0
# Saving model as pickle...
# Upsampling is being applied...
# Building LGBM Upsample Model...
# ROC Curve for test data: 1.0
# Saving model as pickle...
# Downsampling is being applied...
# Building LGBM Downsample Model...
# ROC Curve for test data: 0.9987132371517404
# Saving model as pickle...
# SMOTE is being applied...
# Building SMOTE LGBM Model...
# ROC Curve for test data: 0.9999999999999999
# Saving model as pickle...
# Building LGBM Balanced Bagging Model...
# ROC Curve for test data: 0.9999932630217367
# Saving model as pickle...
# [LightGBM] [Info] Number of positive: 614, number of negative: 1934
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000311 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# ...

# %%
pd.concat(reports)
# Out:
#            Dataset                  Model   f1_test  f1_train  accuracy_test  \
# 0            Fraud          LGBM Baseline  0.328889  0.328289       0.997349
# 1            Fraud          LGBM Upsample  0.866310  0.999960       0.999561
# 2            Fraud        LGBM Downsample  0.089277  1.000000       0.967048
# 3            Fraud             SMOTE LGBM  0.753363  0.999727       0.999034
# 4            Fraud  LGBM Balanced Bagging  0.510949  0.576450       0.998824
# 5            Fraud         LGBM_Imbalance  0.061005  0.065295       0.952442
# 0         Letter-a          LGBM Baseline  0.979730  1.000000       0.998500
# 1         Letter-a          LGBM Upsample  0.986577  1.000000       0.999000
# 2         Letter-a        LGBM Downsample  0.832402  1.000000       0.985000
# 3         Letter-a             SMOTE LGBM  0.986667  1.000000       0.999000
# 4         Letter-a  LGBM Balanced Bagging  0.983165  0.998435       0.998750
# ...

# %%
dataset_infos
# Out:
#        Dataset_Name  Row_Count  Minority_Class_Percent Target_Column
# 0           Abalone       1477                   4.520        target
# 1             Adult      32561                  24.080        target
# 2             Churn       7043                  26.530        target
# 3     Contraceptive       1743                  22.600        target
# 4         Covertype     581012                  14.770        target
# 5             Fraud     284807                   0.172         Class
# 6            Fraud2     250000                   0.500      is_fraud
# 7          Letter-a      20000                   3.940      letter_a
# 8      Letter-vowel      20000                  19.390      is_vowel
# 9         Pendigits      10992                   9.590          is_9
# 10   Sick_euthyroid       2194                  10.050        target
# 11  Splice-junction       3186                  24.070        target
# 12             Wine       6497                   3.760        target

# %%
adult_train = pd.read_csv("adult_train.csv")
adult_test = pd.read_csv("adult_train.csv")

# %%
rep_adult = built_experiment(adult_train, adult_test, "target","Adult")
reports.append(rep_adult)
# Out:
# Running Experiment...
# Dataset Name: Adult
# Target Column: target
# Building LGBM Model...
# ROC Curve for test data: 0.9478740091571467
# Saving model as pickle...
# Upsampling is being applied...
# Building LGBM Upsample Model...
# ROC Curve for test data: 0.9476142397518356
# Saving model as pickle...
# Downsampling is being applied...
# Building LGBM Downsample Model...
# ROC Curve for test data: 0.9444775525074741
# Saving model as pickle...
# SMOTE is being applied...
# Building SMOTE LGBM Model...
# ROC Curve for test data: 0.9398623645914628
# Saving model as pickle...
# Building LGBM Balanced Bagging Model...
# ROC Curve for test data: 0.9499514063843916
# Saving model as pickle...
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 6270, number of negative: 19778
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001304 seconds.
# ...

# %%
pd.concat(reports)
# Out:
#    Dataset                  Model   f1_test  f1_train  accuracy_test  \
# 0    Fraud          LGBM Baseline  0.328889  0.328289       0.997349
# 1    Fraud          LGBM Upsample  0.866310  0.999960       0.999561
# 2    Fraud        LGBM Downsample  0.089277  1.000000       0.967048
# 3    Fraud             SMOTE LGBM  0.753363  0.999727       0.999034
# 4    Fraud  LGBM Balanced Bagging  0.510949  0.576450       0.998824
# ..     ...                    ...       ...       ...            ...
# 1    Adult          LGBM Upsample  0.747197  0.878305       0.853693
# 2    Adult        LGBM Downsample  0.738183  0.881111       0.845401
# 3    Adult             SMOTE LGBM  0.738692  0.917676       0.880682
# 4    Adult  LGBM Balanced Bagging  0.747945  0.747945       0.888168
# 5    Adult         LGBM_Imbalance  0.745256  0.745256       0.851582
#
#     accuracy_train  AUC_test  AUC_train
# 0         0.997468  0.676280   0.665090
# 1         0.999960  0.952730   1.000000
# ...

# %%
dataset_infos
# Out:
#        Dataset_Name  Row_Count  Minority_Class_Percent Target_Column
# 0           Abalone       1477                   4.520        target
# 1             Adult      32561                  24.080        target
# 2             Churn       7043                  26.530        target
# 3     Contraceptive       1743                  22.600        target
# 4         Covertype     581012                  14.770        target
# 5             Fraud     284807                   0.172         Class
# 6            Fraud2     250000                   0.500      is_fraud
# 7          Letter-a      20000                   3.940      letter_a
# 8      Letter-vowel      20000                  19.390      is_vowel
# 9         Pendigits      10992                   9.590          is_9
# 10   Sick_euthyroid       2194                  10.050        target
# 11  Splice-junction       3186                  24.070        target
# 12             Wine       6497                   3.760        target

# %%
churn_train = pd.read_csv("churn_train.csv")
churn_test = pd.read_csv("churn_test.csv")

# %%
churn_train.fillna(0,inplace=True)
churn_test.fillna(0,inplace=True)

# %%
churn_train.target.value_counts()
# Out:
# 0    4138
# 1    1496
# Name: target, dtype: int64

# %%
rep_churn = built_experiment(churn_train, churn_test, "target","Churn")
reports.append(rep_churn)
# Out:
# Running Experiment...
# Dataset Name: Churn
# Target Column: target
# Building LGBM Model...
# ROC Curve for test data: 0.8971451344105501
# Saving model as pickle...
# Upsampling is being applied...
# Building LGBM Upsample Model...
# ROC Curve for test data: 0.897422029459563
# Saving model as pickle...
# Downsampling is being applied...
# Building LGBM Downsample Model...
# ROC Curve for test data: 0.8946582545778257
# Saving model as pickle...
# SMOTE is being applied...
# Building SMOTE LGBM Model...
# ROC Curve for test data: 0.8914234993323465
# Saving model as pickle...
# Building LGBM Balanced Bagging Model...
# ROC Curve for test data: 0.8993965240614034
# Saving model as pickle...
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 1496, number of negative: 4138
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000768 seconds.
# ...

# %%
experiment_results = pd.concat(reports)

# %%
experiment_results
# Out:
#    Dataset                  Model   f1_test  f1_train  accuracy_test  \
# 0    Fraud          LGBM Baseline  0.328889  0.328289       0.997349
# 1    Fraud          LGBM Upsample  0.866310  0.999960       0.999561
# 2    Fraud        LGBM Downsample  0.089277  1.000000       0.967048
# 3    Fraud             SMOTE LGBM  0.753363  0.999727       0.999034
# 4    Fraud  LGBM Balanced Bagging  0.510949  0.576450       0.998824
# ..     ...                    ...       ...       ...            ...
# 1    Churn          LGBM Upsample  0.714286  0.960622       0.838183
# 2    Churn        LGBM Downsample  0.695652  0.981432       0.811214
# 3    Churn             SMOTE LGBM  0.690958  0.961074       0.837473
# 4    Churn  LGBM Balanced Bagging  0.675439  0.885794       0.842441
# 5    Churn         LGBM_Imbalance  0.708029  0.893848       0.829666
#
#     accuracy_train  AUC_test  AUC_train
# 0         0.997468  0.676280   0.665090
# 1         0.999960  0.952730   1.000000
# ...

# %%
experiment_results.to_excel("Experiment_Results.xlsx")
