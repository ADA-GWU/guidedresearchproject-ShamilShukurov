# %%
import pandas as pd
import numpy as np
from os.path import join

# %%
data_folder = r"C:\Users\SukurovSB\Desktop\Guided_Research_New\guidedresearchproject-ShamilShukurov\data"

# %%
exp_results1 = pd.read_excel(join(data_folder,"Experiment_Results.xlsx"))

# %%
exp_results1
# Out:
#    Dataset                  Model   f1_test  f1_train  accuracy_test  \
# 0    Fraud          LGBM Baseline  0.328889  0.328289       0.997349
# 1    Fraud          LGBM Upsample  0.866310  0.999960       0.999561
# 2    Fraud        LGBM Downsample  0.089277  1.000000       0.967048
# 3    Fraud             SMOTE LGBM  0.753363  0.999727       0.999034
# 4    Fraud  LGBM Balanced Bagging  0.510949  0.576450       0.998824
# ..     ...                    ...       ...       ...            ...
# 67   Churn          LGBM Upsample  0.714286  0.960622       0.838183
# 68   Churn        LGBM Downsample  0.695652  0.981432       0.811214
# 69   Churn             SMOTE LGBM  0.690958  0.961074       0.837473
# 70   Churn  LGBM Balanced Bagging  0.675439  0.885794       0.842441
# 71   Churn         LGBM_Imbalance  0.708029  0.893848       0.829666
#
#     accuracy_train  AUC_test  AUC_train
# 0         0.997468  0.676280   0.665090
# 1         0.999960  0.952730   1.000000
# 2         1.000000  0.984910   1.000000
# 3         0.999727  0.972936   0.999864
# 4         0.998942  0.913869   0.971794
# ..             ...       ...        ...
# 67        0.959642  0.897422   0.994100
# 68        0.981283  0.894658   0.998778
# 69        0.961092  0.891423   0.994918
# 70        0.941782  0.899397   0.989227
# 71        0.937522  0.896560   0.991046
#
# [72 rows x 8 columns]

# %%
exp_results1.Dataset.unique()
# Out:
# array(['Fraud', 'Letter-a', 'Wine', 'Abalone', 'Pendigits',
#        'Sick_euthyroid', 'Covertype', 'Letter-vowel', 'Contraceptive',
#        'Splice-junction', 'Adult', 'Churn'], dtype=object)

# %%
dataset_infos = pd.read_csv(join(data_folder,"dataset_infos.csv")).drop(columns = "Unnamed: 0")

# %%
dataset_infos
# Out:
#        Dataset_Name  Row_Count  Minority_Class_Percent Target_Column
# 0           Abalone       1477                   4.520        target
# 1             Adult      32561                  24.080        target
# 2             Churn       7043                  26.530        target
# 3     Contraceptive       1743                  22.600        target
# 4         Covertype     581012                  14.770        target
# 5             Fraud     284807                   0.172         Class
# 6            Fraud2     250000                   0.500      is_fraud
# 7          Letter-a      20000                   3.940      letter_a
# 8      Letter-vowel      20000                  19.390      is_vowel
# 9         Pendigits      10992                   9.590          is_9
# 10   Sick_euthyroid       2194                  10.050        target
# 11  Splice-junction       3186                  24.070        target
# 12             Wine       6497                   3.760        target

# %%
res = exp_results1.merge(dataset_infos, left_on="Dataset",right_on="Dataset_Name").drop(
        columns=["Dataset_Name","accuracy_test","accuracy_train"])

# %%
res.to_excel(join(data_folder,"prepared_results.xlsx"))

# %%
exp_results_syn = pd.read_excel(join(data_folder,"synthetic_exp_results.xlsx"))

# %%
exp_results_syn
# Out:
#           Dataset                  Model   f1_test  f1_train  accuracy_test  \
# 0       Synthetic          LGBM Baseline  0.723974  0.731522       0.844825
# 1       Synthetic          LGBM Upsample  0.748831  0.815346       0.832075
# 2       Synthetic        LGBM Downsample  0.747497  0.814401       0.830425
# 3       Synthetic             SMOTE LGBM  0.750605  0.816522       0.832425
# 4       Synthetic  LGBM Balanced Bagging  0.723171  0.729341       0.845675
# 5       Synthetic         LGBM_Imbalance  0.750564  0.760648       0.834050
# 6    Synthetic_20          LGBM Baseline  0.610554  0.628263       0.878386
# 7    Synthetic_20          LGBM Upsample  0.658572  0.817761       0.847483
# 8    Synthetic_20        LGBM Downsample  0.647813  0.820416       0.836338
# 9    Synthetic_20             SMOTE LGBM  0.648444  0.819858       0.837113
# 10   Synthetic_20  LGBM Balanced Bagging  0.600116  0.619941       0.876807
# 11   Synthetic_20         LGBM_Imbalance  0.660924  0.678798       0.847513
# 12   Synthetic_10          LGBM Baseline  0.459630  0.496862       0.919673
# 13   Synthetic_10          LGBM Upsample  0.508252  0.828465       0.854164
# 14   Synthetic_10        LGBM Downsample  0.481109  0.834560       0.835624
# 15   Synthetic_10             SMOTE LGBM  0.485542  0.830575       0.837166
# 16   Synthetic_10  LGBM Balanced Bagging  0.451348  0.484270       0.919472
# 17   Synthetic_10         LGBM_Imbalance  0.512669  0.544428       0.856209
# 18    Synthetic-5          LGBM Baseline  0.243770  0.376634       0.950600
# 19    Synthetic-5          LGBM Upsample  0.333841  0.840873       0.860752
# 20    Synthetic-5        LGBM Downsample  0.294602  0.863004       0.821048
# 21    Synthetic-5             SMOTE LGBM  0.302655  0.838377       0.832690
# 22    Synthetic-5  LGBM Balanced Bagging  0.239554  0.349245       0.951697
# 23    Synthetic-5         LGBM_Imbalance  0.341886  0.392391       0.862946
# 24    Synthetic-1          LGBM Baseline  0.065089  0.386856       0.988347
# 25    Synthetic-1          LGBM Upsample  0.118785  0.934699       0.905889
# 26    Synthetic-1        LGBM Downsample  0.061582  0.990099       0.778589
# 27    Synthetic-1             SMOTE LGBM  0.083641  0.886983       0.853745
# 28    Synthetic-1  LGBM Balanced Bagging  0.000000  0.184143       0.989195
# 29    Synthetic-1         LGBM_Imbalance  0.086287  0.156748       0.890659
# 30  Synthetic-0.5          LGBM Baseline  0.000000  0.557292       0.994774
# 31  Synthetic-0.5          LGBM Upsample  0.064885  0.974286       0.945517
# 32  Synthetic-0.5        LGBM Downsample  0.026414  1.000000       0.729513
# 33  Synthetic-0.5             SMOTE LGBM  0.043064  0.906577       0.869871
# 34  Synthetic-0.5  LGBM Balanced Bagging  0.000000  0.406977       0.995293
# 35  Synthetic-0.5         LGBM_Imbalance  0.023109  0.053684       0.862125
#
#     accuracy_train  AUC_test  AUC_train
# 0         0.847125  0.874678   0.883579
# 1         0.823693  0.872186   0.886775
# 2         0.823136  0.872359   0.885266
# 3         0.823819  0.872768   0.884604
# 4         0.846962  0.876479   0.885629
# 5         0.839531  0.874030   0.883950
# 6         0.880335  0.873106   0.887362
# 7         0.826780  0.872931   0.892685
# 8         0.828222  0.872523   0.894292
# 9         0.826160  0.870858   0.891235
# 10        0.879248  0.875977   0.891374
# 11        0.853105  0.873447   0.888786
# 12        0.925414  0.867244   0.897319
# 13        0.835009  0.868263   0.904966
# 14        0.841544  0.864179   0.910761
# 15        0.833766  0.865202   0.899893
# 16        0.924433  0.872708   0.909348
# 17        0.866786  0.869093   0.904660
# 18        0.957800  0.848853   0.914946
# 19        0.846062  0.848573   0.923365
# 20        0.868008  0.847693   0.937920
# 21        0.839664  0.841962   0.910751
# 22        0.957304  0.855877   0.938771
# 23        0.872841  0.851571   0.923235
# 24        0.992431  0.773658   0.976945
# 25        0.933329  0.811898   0.977335
# 26        0.990141  0.800328   0.999621
# 27        0.884474  0.811164   0.952562
# 28        0.991177  0.816165   0.996439
# 29        0.898622  0.754930   0.971503
# 30        0.996850  0.785626   0.998998
# 31        0.973694  0.844496   0.993996
# 32        1.000000  0.813332   1.000000
# 33        0.903844  0.843198   0.965534
# 34        0.996219  0.824969   0.999929
# 35        0.866716  0.603408   0.879382
